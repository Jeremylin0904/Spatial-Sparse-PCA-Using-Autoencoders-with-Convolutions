# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1D

# %% [markdown]
# ### Testing MSE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
linearfub1 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub1to5(linear1D).csv')
linearfub2 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub5to10(linear1D).csv')
linearfub3 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub10to13(linear1D).csv')
linearfub4 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub13to16(linear1D).csv')
linearfub5 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub16to19(linear1D).csv')
#linearfub6 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub19to20(linear1D).csv')
linearfub7 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub20to23(linear1D).csv')
linearfub8 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub23to26(linear1D).csv')
linearfub9 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub26to29(linear1D).csv')
linearfub102 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub29to30(linear1D).csv')
linearfub11 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub30to33(linear1D).csv')
linearfub12 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub33to36(linear1D).csv')
linearfub13 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub36to39(linear1D).csv')
linearfub14 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub39to40(linear1D).csv')
linearfub15 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub40to43(linear1D).csv')
linearfub16 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub43to46(linear1D).csv')
linearfub17 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub46to49(linear1D).csv')
linearfub18 = pd.read_csv('/content/drive/MyDrive/master/20240707/2fub49to50(linear1D).csv')


linearres1 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res1to5(linear1D).csv')
linearres2 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res5to10(linear1D).csv')
linearres3 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res10to13(linear1D).csv')
linearres4 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res13to16(linear1D).csv')
linearres5 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res16to19(linear1D).csv')
#linearres6 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res19to20(linear1D).csv')
linearres7 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res20to23(linear1D).csv')
linearres8 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res23to26(linear1D).csv')
linearres9 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res26to29(linear1D).csv')
linearres102 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res29to30(linear1D).csv')
linearres11 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res30to33(linear1D).csv')
linearres12 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res33to36(linear1D).csv')
linearres13 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res36to39(linear1D).csv')
linearres14 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res39to40(linear1D).csv')
linearres15 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res40to43(linear1D).csv')
linearres16 = pd.read_csv('/content/drive/MyDrive/master/20240707/2res43to46(linear1D).csv')
linearres17 = pd.read_csv('/content/drive/MyDrive/master/20240707/res46to49(linear1D).csv')
linearres18 = pd.read_csv('/content/drive/MyDrive/master/20240707/res49to50(linear1D).csv')

# %%
linearfub10 = np.transpose(linearfub1).iloc[1:,:]
linearfub20 = np.transpose(linearfub2).iloc[1:,:]
linearfub30 = np.transpose(linearfub3).iloc[1:,:]
linearfub40 = np.transpose(linearfub4).iloc[1:,:]
linearfub50 = np.transpose(linearfub5).iloc[1:,:]
#linearfub60 = np.transpose(linearfub6).iloc[1:,:]
linearfub70 = np.transpose(linearfub7).iloc[1:,:]
linearfub80 = np.transpose(linearfub8).iloc[1:,:]
linearfub90 = np.transpose(linearfub9).iloc[1:,:]
linearfub100 = np.transpose(linearfub102).iloc[1:,:]
linearfub110 = np.transpose(linearfub11).iloc[1:,:]
linearfub120 = np.transpose(linearfub12).iloc[1:,:]
linearfub130 = np.transpose(linearfub13).iloc[1:,:]
linearfub140 = np.transpose(linearfub14).iloc[1:,:]
linearfub150 = np.transpose(linearfub15).iloc[1:,:]
linearfub160 = np.transpose(linearfub16).iloc[1:,:]
linearfub170 = np.transpose(linearfub17).iloc[1:,:]
linearfub180 = np.transpose(linearfub18).iloc[1:,:]


linearres10 = np.transpose(linearres1).iloc[1:,:]
linearres20 = np.transpose(linearres2).iloc[1:,:]
linearres30 = np.transpose(linearres3).iloc[1:,:]
linearres40 = np.transpose(linearres4).iloc[1:,:]
linearres50 = np.transpose(linearres5).iloc[1:,:]
#linearres60 = np.transpose(linearres6).iloc[1:,:]
linearres70 = np.transpose(linearres7).iloc[1:,:]
linearres80 = np.transpose(linearres8).iloc[1:,:]
linearres90 = np.transpose(linearres9).iloc[1:,:]
linearres100 = np.transpose(linearres102).iloc[1:,:]
linearres110 = np.transpose(linearres11).iloc[1:,:]
linearres120 = np.transpose(linearres12).iloc[1:,:]
linearres130 = np.transpose(linearres13).iloc[1:,:]
linearres140 = np.transpose(linearres14).iloc[1:,:]
linearres150 = np.transpose(linearres15).iloc[1:,:]
linearres160 = np.transpose(linearres16).iloc[1:,:]
linearres170 = np.transpose(linearres17).iloc[1:,:]
linearres180 = np.transpose(linearres18).iloc[1:,:]

# %%
import matplotlib.pyplot as plt

data = np.concatenate([linearres10, linearres20, linearres30, linearres40,linearres50, linearres70, linearres80, linearres90, linearres100, linearres110, linearres120, linearres130, linearres140, linearres150, linearres160, linearres170, linearres180])
labels = ['PCA','SPCA','SAE', 'SAE-C']
data = pd.DataFrame(data)
saec = []
saecindex = []
for i in range(50):
    saec.append(np.min(data.iloc[i,3:7]))
    saecindex.append(np.argmin(data.iloc[i,3:7]))
data['SAEC'] = saec
plt.boxplot(data.iloc[:,[0,1,2,7]])
plt.xticks(range(1, len(labels) + 1), labels,fontsize = 16)  # 设置刻度标签
plt.xlabel('Methods',fontsize = 16)  # 设置x轴标签
plt.title(r'1D simulation: Testing MSE', fontsize = 20)

plt.show()

# %% [markdown]
# ### F-norm

# %%
import matplotlib.pyplot as plt

data1 = np.concatenate([linearfub10, linearfub20, linearfub30,linearfub40, linearfub50, linearfub70, linearfub80, linearfub90, linearfub100, linearfub110, linearfub120, linearfub130, linearfub140, linearfub150, linearfub160,  linearfub170, linearfub180])
labels = ['PCA','SPCA', 'SAE', 'SAE-C']
saecfub = []
for i in range(50):
    saecfub.append(data1[i,saecindex[i]+3])

data1 = pd.DataFrame(data1)
data1['saec']=saecfub
plt.boxplot(data1.iloc[:,[0,1,2,7]])
plt.xticks(range(1, len(labels) + 1), labels,fontsize = 16)  # 设置刻度标签
plt.xlabel('Methods',fontsize = 16)  # 设置x轴标签
plt.title(r'1D simulation: $\|V_K V_K^{\prime} -\tilde{V}_K (\tilde{V}_K^{\prime}\tilde{V}_K)^{-1}\tilde{V}_K^{\prime} \|_F$', fontsize = 16)



plt.show()

# %% [markdown]
# #2D

# %% [markdown]
# ## Testing MSE

# %%
### 1D linear Boxplots
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

linearfub1 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub0to5(linear2D).csv')
linearfub2 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub5to10(linear2D).csv')
linearfub3 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub10to15(linear2D).csv')
linearfub4 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub15to20(linear2D).csv')
linearfub5 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub20to25(linear2D).csv')
linearfub6 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub25to30(linear2D).csv')
linearfub7 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub30to35(linear2D).csv')
linearfub8 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub35to40(linear2D).csv')
linearfub9 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub40to45(linear2D).csv')
linearfub102 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub45to50(linear2D).csv')
linearfub11 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub50to55(linear2D).csv')
linearfub12 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub55to60(linear2D).csv')
linearfub13 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub60to65(linear2D).csv')
linearfub14 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub65to70(linear2D).csv')
linearfub15 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub70to75(linear2D).csv')
linearfub16 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub75to80(linear2D).csv')
linearfub17 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub80to85(linear2D).csv')
linearfub18 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub85to90(linear2D).csv')
linearfub19 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub90to95(linear2D).csv')
linearfub202 = pd.read_csv('/content/drive/MyDrive/master/20240707/fub95to100(linear2D).csv')


linearres1 = pd.read_csv('/content/drive/MyDrive/master/20240707/res0to5(linear2D).csv')
linearres2 = pd.read_csv('/content/drive/MyDrive/master/20240707/res5to10(linear2D).csv')
linearres3 = pd.read_csv('/content/drive/MyDrive/master/20240707/res10to15(linear2D).csv')
linearres4 = pd.read_csv('/content/drive/MyDrive/master/20240707/res15to20(linear2D).csv')
linearres5 = pd.read_csv('/content/drive/MyDrive/master/20240707/res20to25(linear2D).csv')
linearres6 = pd.read_csv('/content/drive/MyDrive/master/20240707/res25to30(linear2D).csv')
linearres7 = pd.read_csv('/content/drive/MyDrive/master/20240707/res30to35(linear2D).csv')
linearres8 = pd.read_csv('/content/drive/MyDrive/master/20240707/res35to40(linear2D).csv')
linearres9 = pd.read_csv('/content/drive/MyDrive/master/20240707/res40to45(linear2D).csv')
linearres102 = pd.read_csv('/content/drive/MyDrive/master/20240707/res45to50(linear2D).csv')
linearres11 = pd.read_csv('/content/drive/MyDrive/master/20240707/res50to55(linear2D).csv')
linearres12 = pd.read_csv('/content/drive/MyDrive/master/20240707/res55to60(linear2D).csv')
linearres13 = pd.read_csv('/content/drive/MyDrive/master/20240707/res60to65(linear2D).csv')
linearres14 = pd.read_csv('/content/drive/MyDrive/master/20240707/res65to70(linear2D).csv')
linearres15 = pd.read_csv('/content/drive/MyDrive/master/20240707/res70to75(linear2D).csv')
linearres16 = pd.read_csv('/content/drive/MyDrive/master/20240707/res75to80(linear2D).csv')
linearres17 = pd.read_csv('/content/drive/MyDrive/master/20240707/res80to85(linear2D).csv')
linearres18 = pd.read_csv('/content/drive/MyDrive/master/20240707/res85to90(linear2D).csv')
linearres19 = pd.read_csv('/content/drive/MyDrive/master/20240707/res90to95(linear2D).csv')
linearres202 = pd.read_csv('/content/drive/MyDrive/master/20240707/res95to100(linear2D).csv')




linearfub10 = np.transpose(linearfub1).iloc[1:,:]
linearfub20 = np.transpose(linearfub2).iloc[1:,:]
linearfub30 = np.transpose(linearfub3).iloc[1:,:]
linearfub40 = np.transpose(linearfub4).iloc[1:,:]
linearfub50 = np.transpose(linearfub5).iloc[1:,:]
linearfub60 = np.transpose(linearfub6).iloc[1:,:]
linearfub70 = np.transpose(linearfub7).iloc[1:,:]
linearfub80 = np.transpose(linearfub8).iloc[1:,:]
linearfub90 = np.transpose(linearfub9).iloc[1:,:]
linearfub100 = np.transpose(linearfub102).iloc[1:,:]
linearfub110 = np.transpose(linearfub11).iloc[1:,:]
linearfub120 = np.transpose(linearfub12).iloc[1:,:]
linearfub130 = np.transpose(linearfub13).iloc[1:,:]
linearfub140 = np.transpose(linearfub14).iloc[1:,:]
linearfub150 = np.transpose(linearfub15).iloc[1:,:]
linearfub160 = np.transpose(linearfub16).iloc[1:,:]
linearfub170 = np.transpose(linearfub17).iloc[1:,:]
linearfub180 = np.transpose(linearfub18).iloc[1:,:]
linearfub190 = np.transpose(linearfub19).iloc[1:,:]
linearfub200 = np.transpose(linearfub202).iloc[1:,:]


linearres10 = np.transpose(linearres1).iloc[1:,:]
linearres20 = np.transpose(linearres2).iloc[1:,:]
linearres30 = np.transpose(linearres3).iloc[1:,:]
linearres40 = np.transpose(linearres4).iloc[1:,:]
linearres50 = np.transpose(linearres5).iloc[1:,:]
linearres60 = np.transpose(linearres6).iloc[1:,:]
linearres70 = np.transpose(linearres7).iloc[1:,:]
linearres80 = np.transpose(linearres8).iloc[1:,:]
linearres90 = np.transpose(linearres9).iloc[1:,:]
linearres100 = np.transpose(linearres102).iloc[1:,:]
linearres110 = np.transpose(linearres11).iloc[1:,:]
linearres120 = np.transpose(linearres12).iloc[1:,:]
linearres130 = np.transpose(linearres13).iloc[1:,:]
linearres140 = np.transpose(linearres14).iloc[1:,:]
linearres150 = np.transpose(linearres15).iloc[1:,:]
linearres160 = np.transpose(linearres16).iloc[1:,:]
linearres170 = np.transpose(linearres17).iloc[1:,:]
linearres180 = np.transpose(linearres18).iloc[1:,:]
linearres190 = np.transpose(linearres19).iloc[1:,:]
linearres200 = np.transpose(linearres202).iloc[1:,:]

# %%
print(linearfub10.shape)
print(linearfub20.shape)
print(linearfub30.shape)
print(linearfub40.shape)
print(linearfub50.shape)
print(linearfub60.shape)
print(linearfub70.shape)
print(linearfub80.shape)
print(linearfub90.shape)
print(linearfub100.shape)
print(linearfub110.shape)
print(linearfub120.shape)
print(linearfub130.shape)
print(linearfub140.shape)
print(linearfub150.shape)
print(linearfub160.shape)
print(linearfub170.shape)
print(linearfub180.shape)
print(linearfub190.shape)
print(linearfub200.shape)
# Out:
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)
# (5, 7)

# %%
data.shape
# Out:
# (100, 9)

# %%
import matplotlib.pyplot as plt

data = np.concatenate([linearres10, linearres20, linearres30, linearres40,linearres50, linearres60,linearres70, linearres80, linearres90, linearres100,linearres110, linearres120, linearres130, linearres140, linearres150, linearres160, linearres170, linearres180, linearres190, linearres200])
labels = ['PCA','SPCA','SAE', 'SAE-C']
data = pd.DataFrame(data)
saec = []
saecindex = []
for i in range(100):
    saec.append(np.min(data.iloc[i,3:7]))
    saecindex.append(np.argmin(data.iloc[i,3:7]))
data['SAEC'] = saec
data['SAECindex'] = saecindex
plt.boxplot(data.iloc[:,[0,1,2,7]])
plt.xticks(range(1, len(labels) + 1), labels, fontsize=16)  # 设置刻度标签
plt.xlabel('Methods', fontsize=16)  # 设置x轴标签
plt.yticks(np.round(np.linspace(0.98,1.05, 8),2), fontsize=16)
plt.title(r'2D simulation: Testing MSE', fontsize=20)

plt.show()

# %% [markdown]
# ## F-norm

# %%
import matplotlib.pyplot as plt

data1 = np.concatenate([linearfub10, linearfub20, linearfub30,linearfub40, linearfub50,linearfub60, linearfub70, linearfub80, linearfub90, linearfub100, linearfub110,linearfub120,linearfub130,linearfub140,linearfub150, linearfub160,  linearfub170, linearfub180, linearfub190,linearfub200])
labels = ['PCA','SPCA', 'SAE', 'SAE-C']
saecfub = []
for i in range(100):
    saecfub.append(data1[i,saecindex[i]+3])

data1 = pd.DataFrame(data1)
data1['saec']=saecfub
plt.boxplot(data1.iloc[:,[0,1,2,7]])
plt.xticks(range(1, len(labels) + 1), labels, fontsize=16)  # 设置刻度标签
plt.xlabel('Methods', fontsize=16)  # 设置x轴标签
plt.yticks(np.linspace(0.2,0.8, 7), fontsize=16)
plt.title(r'2D simulation: $\|V_K V_K^{\prime} -\tilde{V}_K (\tilde{V}_K^{\prime}\tilde{V}_K)^{-1}\tilde{V}_K^{\prime} \|_F$', fontsize = 16)


plt.show()

# %% [markdown]
# # 2D nonlinear

# %% [markdown]
# ### Testing MSE

# %%
### 1D linear Boxplots
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



linearres1 = pd.read_csv('/content/drive/MyDrive/master/20240707/res1to10(nonlinear2D).csv')
linearres2 = pd.read_csv('/content/drive/MyDrive/master/20240707/res10to20(nonlinear2D).csv')
linearres3 = pd.read_csv('/content/drive/MyDrive/master/20240707/res20to30(nonlinear2D).csv')

linearres4 = pd.read_csv('/content/drive/MyDrive/master/20240707/res30to40(nonlinear2D).csv')

linearres5 = pd.read_csv('/content/drive/MyDrive/master/20240707/res40to50(nonlinear2D).csv')

#linearres6 = pd.read_csv('/content/drive/MyDrive/master/20240707/res50to60(nonlinear2D).csv')
linearres7 = pd.read_csv('/content/drive/MyDrive/master/20240707/res60to70(nonlinear2D).csv')
'''
linearres8 = pd.read_csv('/content/drive/MyDrive/master/20240707/res70to80(nonlinear2D).csv')
linearres9 = pd.read_csv('/content/drive/MyDrive/master/20240707/res80to90(nonlinear2D).csv')
linearres10 = pd.read_csv('/content/drive/MyDrive/master/20240707/res90to100(nonlinear2D).csv')
'''


linearres11 = pd.read_csv('/content/drive/MyDrive/master/20240707/res0to10(nonlinear2D_dense).csv')
linearres21 = pd.read_csv('/content/drive/MyDrive/master/20240707/res10to20(nonlinear2D_dense).csv')
linearres31 = pd.read_csv('/content/drive/MyDrive/master/20240707/res20to30(nonlinear2D_dense).csv')
linearres41 = pd.read_csv('/content/drive/MyDrive/master/20240707/res30to40(nonlinear2D_dense).csv')

linearres51 = pd.read_csv('/content/drive/MyDrive/master/20240707/res40to50(nonlinear2D_dense).csv')
#linearres61 = pd.read_csv('/content/drive/MyDrive/master/20240707/res50to60(nonlinear2D_dense).csv')
linearres71 = pd.read_csv('/content/drive/MyDrive/master/20240707/res60to70(nonlinear2D_dense).csv')
'''
linearres81 = pd.read_csv('/content/drive/MyDrive/master/20240707/res70to80(nonlinear2D_dense).csv')
linearres91 = pd.read_csv('/content/drive/MyDrive/master/20240707/res80to90(nonlinear2D_dense).csv')
linearres101 = pd.read_csv('/content/drive/MyDrive/master/20240707/res90to100(nonlinear2D_dense).csv')
'''



linearres10 = np.transpose(linearres1).iloc[1:,:]
linearres20 = np.transpose(linearres2).iloc[1:,:]
linearres30 = np.transpose(linearres3).iloc[1:,:]

linearres40 = np.transpose(linearres4).iloc[1:,:]

linearres50 = np.transpose(linearres5).iloc[1:,:]
#linearres60 = np.transpose(linearres6).iloc[1:,:]

linearres70 = np.transpose(linearres7).iloc[1:,:]
'''
linearres80 = np.transpose(linearres8).iloc[1:,:]
linearres90 = np.transpose(linearres9).iloc[1:,:]
linearres100 = np.transpose(linearres102).iloc[1:,:]
'''
linearres12 = np.transpose(linearres11).iloc[1:,:]
linearres22 = np.transpose(linearres21).iloc[1:,:]
linearres32 = np.transpose(linearres31).iloc[1:,:]

linearres42 = np.transpose(linearres41).iloc[1:,:]

linearres52 = np.transpose(linearres51).iloc[1:,:]
#linearres62 = np.transpose(linearres61).iloc[1:,:]
linearres72 = np.transpose(linearres71).iloc[1:,:]
'''
linearres82 = np.transpose(linearres81).iloc[1:,:]
linearres92 = np.transpose(linearres91).iloc[1:,:]
linearres102 = np.transpose(linearres101).iloc[1:,:]
'''
# Out:
# '\nlinearres82 = np.transpose(linearres81).iloc[1:,:]\nlinearres92 = np.transpose(linearres91).iloc[1:,:]\nlinearres102 = np.transpose(linearres101).iloc[1:,:]\n'

# %%
import matplotlib.pyplot as plt

data = np.concatenate([linearres10, linearres20, linearres30, linearres40, linearres50, linearres70])
data2 = np.concatenate([linearres12, linearres22, linearres32, linearres42, linearres52, linearres72])
labels = ['PCA', 'nAE-C (w/ Conv)', 'nAE-C (w/o Conv)']
data = pd.DataFrame(data)
data2 = pd.DataFrame(data2)
saec = []
saecindex = []

plt.boxplot(pd.concat([data.iloc[:50,[0,5]], data2.iloc[:50,5]],axis = 1))
plt.xticks(range(1, len(labels) + 1), labels, fontsize=12)  # 设置刻度标签
plt.xlabel('Methods', fontsize=16)  # 设置x轴标签
#plt.yticks(np.round(np.linspace(0.98,1.05, 8),2), fontsize=16)
plt.title(r'2D simulation: Testing MSE', fontsize=20)

plt.show()
